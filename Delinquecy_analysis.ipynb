# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('Delinquency_prediction_dataset.xlsx', index_col=0, header=0)

# %%
df.dtypes

# %%
df.fillna(0, inplace=True)

# %%
df.to_csv('cleaned_dataset.csv', index=False)

# %%
plt.scatter(df['Age'], df['Income'])
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Age vs Income")
plt.show()

# %%
plt.hist(df['Credit_Score'], bins=20)
plt.title("Credit Score Distribution")
plt.xlabel("Credit Score")
plt.show()

# %%
df.head()

# %%
df.tail()

# %%
df.columns

# %%
plt.scatter(df['Income'], df['Loan_Balance'])
plt.xlabel("Income")
plt.ylabel("Loan Balance")
plt.title("Income vs Loan Balance")
plt.show()

# %%
counts = df['Employment_Status'].value_counts()

plt.pie(counts, labels=counts.index, autopct='%1.1f%%')
plt.title("Employment Status Distribution")
plt.show()

# %%
plt.bar(df['Age'], df['Income'])
plt.title("Income vs Employment Status")
plt.xlabel("Age")
plt.ylabel("Income")
plt.title("Income by Age")
plt.show()

# %%
df['Employment_Status'] = df['Employment_Status'].replace({
    'EMP': 'Employed',
    'employed': 'Employed'
})
