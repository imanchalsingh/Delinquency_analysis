# %% [markdown]
# ### Visualizations of Delinquency Prediction Data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dpd = pd.read_csv('cleaned_dataset.csv')

# %%
dpd.head()

# %%
plt.hist('Credit_Card_Type') plt.show()

# %%
plt.scatter('Income', 'Loan_Balance') plt.show()
